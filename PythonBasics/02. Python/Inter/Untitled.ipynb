# %%
import pandas as pd
data = pd.read_csv('./athletes.csv')
data
# Out:
#     AthleteID  FirstName  ...     DatePro RecordAnnualEarningsUSD
# 0           1       John  ...  2004-05-05                   15000
# 1           2      Seble  ...  2006-05-05                   17000
# 2           3       Eric  ...  2007-05-05                    4000
# 3           4    Patrick  ...  2004-05-05                    6500
# 4           5      Nesta  ...  2010-02-05                   10000
# 5           6    Iolanta  ...  2010-02-04                    3000
# 6           7     Noxolo  ...  2012-08-20                   12000
# 7           8  Boitumelo  ...  2014-05-10                    4250
# 8           9     Kanako  ...  2014-10-23                   15000
# 9          10     Cammie  ...  2015-05-17                    8000
# 10         11     Themar  ...  2020-03-17                   25000
# 11         12     Darina  ...  2016-05-05                    2500
# 12         13     Monica  ...  2018-11-12                    4500
# ...

# %%
i = 3
print(f"Name: {data['FirstName'][i]}, Discipline: {data['Discipline'][i]}, PB: {data['PB'][i]}")
# Out:
# Name: Patrick, Discipline: 100m, PB: 11.0

# %%
print('This is num %f'.format(10.22))
# Out:
# This is num \s%f
